# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv('train.csv')

# %%
df1
# Out:
#       Sample ID        x1        x2        x3        x4        x5        x6  \
# 0             1  0.335203 -0.784238  1.748584  0.689819  1.345981  2.401481
# 1             2 -0.367194  1.214139 -1.239823  0.913640 -1.108813  0.842107
# 2             3 -0.223586 -0.004247 -0.753329 -0.231245  0.569146  2.014164
# 3             4 -1.436968  1.467864  0.858960  0.139044  0.295012 -1.267011
# 4             5  0.762653  0.087473 -1.692083 -1.777014 -0.349183  1.095108
# ...         ...       ...       ...       ...       ...       ...       ...
# 7995       7996  0.797064  0.088848  1.043295 -1.396315  1.653988 -1.805195
# 7996       7997 -1.751327  0.683739  0.531284  0.469559 -1.191279  0.138086
# 7997       7998 -1.531730  1.239963  0.375153 -0.604610  0.191582  0.452269
# 7998       7999 -1.617570  0.943902  0.721368  0.451608 -0.036600 -1.227781
# 7999       8000 -0.805792  0.042070  0.538674  0.616728 -0.532901  1.329784
#
# ...

# %%
np.random.seed(19)
df = df1.sample(frac = 0.8)
 

df_test = df1.drop(df.index)

# %%
df0 = df.loc[df['t'] == 0]
df1 = df.loc[df['t'] == 1]
df2 = df.loc[df['t'] == 2]
df3 = df.loc[df['t'] == 3]
df4 = df.loc[df['t'] == 4]
df5 = df.loc[df['t'] == 5]
df6 = df.loc[df['t'] == 6]
df7 = df.loc[df['t'] == 7]
df8 = df.loc[df['t'] == 8]
df9 = df.loc[df['t'] == 9]

# %%
plt.figure(figsize=(8,5))
plt.scatter(df0['x1'],df0['x2'], c='black', label = "Class = 0")
plt.scatter(df1['x1'],df1['x2'], c = 'c', label = "Class = 1")

plt.scatter(df2['x1'],df2['x2'], c = 'r', label = "Class = 2")
#plt.scatter(df3['x1'],df3['x2'], c = 'g', label = "Class = 3")


plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df3['x1'],df3['x2'], c='black',label = "Class = 3")
plt.scatter(df4['x1'],df4['x2'], c = 'c', label = "Class = 4")

plt.scatter(df5['x1'],df5['x2'], c = 'r', label = "Class = 5")
#plt.scatter(df3['x1'],df3['x2'], c = 'g', label = "Class = 3")


plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df6['x1'],df6['x2'], c='black',label = "Class = 6")
plt.scatter(df7['x1'],df7['x2'], c = 'brown', label = "Class = 7")

plt.scatter(df8['x1'],df8['x2'], c = 'r', label = "Class = 8")
plt.scatter(df9['x1'],df9['x2'], c = 'cyan', label = "Class = 9")


plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
cols_to_norm = ['x1','x2','x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','x14','x15','x16','x17','x18','x19','x20','x21','x22','x23','x24','x25']
df1[cols_to_norm] = scaler.fit_transform(df1[cols_to_norm])

# %%
df.head()
# Out:
#       Sample ID        x1        x2        x3        x4        x5        x6  \
# 5980       5981 -0.380989 -0.789994 -1.253835  1.731512  0.073514 -0.257684
# 2927       2928 -0.324199 -1.993323  0.158867 -0.096828  0.227548 -0.519764
# 4286       4287  1.054323  0.660415  0.443741  0.874806  3.013686 -1.775060
# 279         280 -0.444533 -1.209893 -0.553916 -0.343899 -0.905226 -0.051751
# 3020       3021 -1.550444  1.103339  0.846147 -0.006507  0.233970 -1.344184
#
#             x7        x8        x9  ...       x17       x18       x19  \
# 5980 -1.073663 -0.891428  0.893266  ...  1.261837  1.499700 -0.110024
# 2927 -0.988971  0.207026 -1.387650  ... -0.882885  0.274789 -0.930735
# 4286  1.225677 -1.055536 -0.003790  ... -0.973714  0.000030 -0.023964
# 279  -1.073038  1.110657  0.738587  ...  1.094746  0.903249  0.366947
# 3020  0.174693  0.536376  0.974614  ... -0.145931 -0.274907 -0.053028
#
#            x20       x21       x22       x23       x24       x25  t
# ...

# %%
X1 = df1.drop('t',axis = 'columns')
X = X1.drop('Sample ID', axis = 'columns')

y = df1.t

# %%
np.random.seed(22)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

# %%
# Out:
# 0       6
# 1       3
# 2       6
# 3       1
# 4       5
#        ..
# 7995    2
# 7996    1
# 7997    1
# 7998    1
# 7999    6
# Name: t, Length: 8000, dtype: int64

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn import svm

# %% [markdown]
# Polynomial

# %%
c = []
d = []
i = 1
l = []
g = []
while i<=10:
    model = svm.NuSVC(kernel = 'poly' , degree =i).fit(X_train, y_train)

    score = model.score(X_test, y_test)
    sc = model.score(X_train,y_train)
    d.append(score)
    c.append(model)
    g.append(sc)
    
    k = i
    l.append(k)

    
    i = i+1

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation')
plt.plot(l,g, c='r', label = 'Training')
#plt.xscale("log")
plt.xlabel("Degree")
plt.ylabel("Score")
plt.legend()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
cols_to_norm = ['x1','x2','x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','x14','x15','x16','x17','x18','x19','x20','x21','x22','x23','x24','x25']
df_test[cols_to_norm] = scaler.fit_transform(df_test[cols_to_norm])

# %%
Xt = df_test.drop('t',axis='columns')

# %%
model = svm.NuSVC(kernel = 'poly' , degree =3,nu = i).fit(X_train, y_train)

# %%
model.score(X_test, y_test)
# Out:
# 0.955

# %%
y_pred = model.predict(Xt)


np.savetxt("pred_Poly.csv", y_pred, delimiter=",")

# %%
c = []
d = []
i = 0.8
l = []
g = []
while i >=0.0001:
    
    
    model = svm.NuSVC(kernel = 'poly' , degree =3,nu = i).fit(X_train, y_train)
    sc = model.score(X_train, y_train)
    score = model.score(X_test, y_test)
    g.append(sc)
    d.append(score)
    c.append(model)
    
    k = i
    l.append(k)

    
    i = i - 0.01

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation')
plt.plot(l,g, c='r', label = 'Training')
#plt.xscale("log")
plt.xlabel("Degree")
plt.ylabel("Score")
plt.legend()

# %%
model = svm.NuSVC(kernel = 'poly' , degree =3,nu = 0.11, decision_function_shape='ovr').fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9575

# %%
model = svm.NuSVC(kernel = 'poly' , degree =3,nu = 0.11).fit(X, y)

# %%
y_pred = model.predict(Xt)


np.savetxt("pred_PolyNu.csv", y_pred, delimiter=",")

# %%
c = []
d = []
i = 0.8
l = []
g = []
while i >=0.0001:
    
    
    model = svm.NuSVC(kernel = 'rbf' ,nu = i).fit(X_train, y_train)
    sc = model.score(X_train, y_train)
    score = model.score(X_test, y_test)
    g.append(sc)
    d.append(score)
    c.append(model)
    
    k = i
    l.append(k)

    
    i = i - 0.01

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation')
plt.plot(l,g, c='r', label = 'Training')
#plt.xscale("log")
plt.xlabel("nu")
plt.ylabel("Score")
plt.legend()

# %%
model = svm.NuSVC(kernel = 'rbf' ,nu = 0.08,decision_function_shape='ovo').fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9675

# %%
model = svm.NuSVC(kernel = 'rbf' ,nu = 0.08).fit(X, y)

y_pred = model.predict(Xt)


np.savetxt("pred_RBFnuSc.csv", y_pred, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 3>()
#       1 model = svm.NuSVC(kernel = 'rbf' ,nu = 0.08).fit(X, y)
# ----> 3 y_pred = model.predict(Xt)
#       6 np.savetxt("pred_RBFnuSc.csv", y_pred, delimiter=",")
#
# NameError: name 'Xt' is not defined

# %%
c = []
d = []
i = 0.8
l = []
g = []
while i >=0.001:
    
    
    model = svm.NuSVC(kernel = 'sigmoid',  nu =  i).fit(X_train, y_train)
    sc = model.score(X_train, y_train)
    score = model.score(X_test, y_test)
    g.append(sc)
    d.append(score)
    c.append(model)
    
    k = i
    l.append(k)

    
    i = i - 0.01

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation')
plt.plot(l,g, c='r', label = 'Training')
#plt.xscale("log")
plt.xlabel("nu")
plt.ylabel("Score")
plt.legend()

# %%
from sklearn.svm import LinearSVC

# %%
c = []
d = []
i = 1e-5
l = []
g = []
while i<=1e5:
    model = OneVsRestClassifier(LinearSVC(random_state=0, C = i)).fit(X_train, y_train)
    sc = model.score(X_train, y_train)
    score = model.score(X_test, y_test)
    g.append(sc)
    d.append(score)
    c.append(model)
    
    k = i
    l.append(k)

    
    i = i*10
# Out:
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation Score')
plt.plot(l,g, c='r',label = 'Training Score')
plt.xscale("log")
plt.xlabel("C")
plt.ylabel("Score")
plt.legend()

# %%
c = []
d = []
i = 1e-1
l = []
g = []
while i<=40:
    model = OneVsRestClassifier(LinearSVC(random_state=0, C = i)).fit(X_train, y_train)
    sc = model.score(X_train, y_train)
    score = model.score(X_test, y_test)
    g.append(sc)
    d.append(score)
    c.append(model)
    
    k = i
    l.append(k)

    
    i = i*2
# Out:
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation Score')
plt.plot(l,g, c='r',label = 'Training Score')
#plt.xscale("log")
plt.xlabel("C")
plt.ylabel("Score")
plt.legend()

# %%
c = []
d = []
i = 10
l = []
g = []
while i >=0.1:
    model = OneVsRestClassifier(LinearSVC(random_state=0, C = i)).fit(X_train, y_train)
    sc = model.score(X_train, y_train)
    score = model.score(X_test, y_test)
    g.append(sc)
    d.append(score)
    c.append(model)
    
    k = i
    l.append(k)

    
    i = i - 0.1
# Out:
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation Score')
plt.plot(l,g, c='r',label = 'Training Score')
#plt.xscale("log")
plt.xlabel("C")
plt.ylabel("Score")
plt.legend()

# %%
c = []
d = []
i = 8
l = []
g = []
while i >=7:
    model = OneVsRestClassifier(LinearSVC(random_state=0, C = i)).fit(X_train, y_train)
    sc = model.score(X_train, y_train)
    score = model.score(X_test, y_test)
    g.append(sc)
    d.append(score)
    c.append(model)
    
    k = i
    l.append(k)

    
    i = i - 0.1
# Out:
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation Score')
plt.plot(l,g, c='r',label = 'Training Score')
#plt.xscale("log")
plt.xlabel("C")
plt.ylabel("Score")
plt.legend()

# %%
model = OneVsRestClassifier(LinearSVC(random_state=0, C = 7.6)).fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
y_pred = model.predict(Xt)


np.savetxt("pred_LinOneVRest.csv", y_pred, delimiter=",")

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, shuffle = True)
model = OneVsOneClassifier(LinearSVC(random_state=0, C = 0.5)).fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.896875

# %%
from sklearn.multiclass import OneVsOneClassifier

# %%
c = []
d = []
i = 1e-5
l = []
g = []
while i<=1e5:
    model = OneVsOneClassifier(LinearSVC(random_state=0, C = i)).fit(X_train, y_train)
    sc = model.score(X_train, y_train)
    score = model.score(X_test, y_test)
    g.append(sc)
    d.append(score)
    c.append(model)
    
    k = i
    l.append(k)

    
    i = i*10
# Out:
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation Score')
plt.plot(l,g, c='r',label = 'Training Score')
plt.xscale("log")
plt.xlabel("C")
plt.ylabel("Score")
plt.legend()

# %%
c = []
d = []
i = 1e-1
l = []
g = []
while i<=1e1:
    model = OneVsOneClassifier(LinearSVC(random_state=0, C = i)).fit(X_train, y_train)
    sc = model.score(X_train, y_train)
    score = model.score(X_test, y_test)
    g.append(sc)
    d.append(score)
    c.append(model)
    
    k = i
    l.append(k)

    
    i = i*2
# Out:
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation Score')
plt.plot(l,g, c='r',label = 'Training Score')
#plt.xscale("log")
plt.xlabel("C")
plt.ylabel("Score")
plt.legend()

# %%
c = []
d = []
i = 2
l = []
g = []
while i >=0:
    model = OneVsOneClassifier(LinearSVC(random_state=0, C = i)).fit(X_train, y_train)
    sc = model.score(X_train, y_train)
    score = model.score(X_test, y_test)
    g.append(sc)
    d.append(score)
    c.append(model)
    
    k = i
    l.append(k)

    
    i = i - 0.1
# Out:
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(l,d, c='blue', label = 'Testing/Validation Score')
plt.plot(l,g, c='r',label = 'Training Score')
#plt.xscale("log")
plt.xlabel("C")
plt.ylabel("Score")
plt.legend()

# %%
model = OneVsOneClassifier(LinearSVC(random_state=0, C = 1.5)).fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Leovo\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
dft = pd.read_csv('test.csv')
dft
# Out:
#       Sample ID        x1        x2        x3        x4        x5        x6  \
# 0             1  0.036550  0.641572 -0.519057  0.460712  0.570700  0.222309
# 1             2 -1.004027  0.534250 -0.259404  0.310052  0.755525 -0.267865
# 2             3 -1.147219  0.334078 -0.389740 -0.508234  0.184723  1.956903
# 3             4 -0.506680 -1.361191 -0.576784  0.064672 -0.049516 -0.111892
# 4             5 -1.546926  0.966659  0.460473  0.139549 -0.777357 -0.015657
# ...         ...       ...       ...       ...       ...       ...       ...
# 1995       1996 -1.582811  0.864609  0.612178  0.358372 -1.142419  0.675760
# 1996       1997  1.744843  0.623868 -0.469064  1.619294 -0.944036 -0.744784
# 1997       1998 -1.745249  0.983623  0.502273  0.282896 -0.758385 -0.294727
# 1998       1999 -1.235580 -0.180367  0.232004 -1.738035  0.262606 -0.283989
# 1999       2000  0.295303  0.586335 -1.943268  0.487705 -0.199133 -1.727402
#
# ...

# %%
Xt = dft.iloc[:,1:26]
Xt
# Out:
#             x1        x2        x3        x4        x5        x6        x7  \
# 0     0.036550  0.641572 -0.519057  0.460712  0.570700  0.222309  0.087710
# 1    -1.004027  0.534250 -0.259404  0.310052  0.755525 -0.267865  0.803048
# 2    -1.147219  0.334078 -0.389740 -0.508234  0.184723  1.956903  1.366785
# 3    -0.506680 -1.361191 -0.576784  0.064672 -0.049516 -0.111892  0.502428
# 4    -1.546926  0.966659  0.460473  0.139549 -0.777357 -0.015657  1.188006
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -1.582811  0.864609  0.612178  0.358372 -1.142419  0.675760  0.986953
# 1996  1.744843  0.623868 -0.469064  1.619294 -0.944036 -0.744784  0.073100
# 1997 -1.745249  0.983623  0.502273  0.282896 -0.758385 -0.294727  0.434684
# 1998 -1.235580 -0.180367  0.232004 -1.738035  0.262606 -0.283989  1.539323
# 1999  0.295303  0.586335 -1.943268  0.487705 -0.199133 -1.727402 -0.849607
#
# ...

# %%
y_pred = model.predict(Xt)


np.savetxt("pred_LinOneVOne.csv", y_pred, delimiter=",")

# %%
X
# Out:
#             x1        x2        x3      x3.1        x5        x6        x7  \
# 0     0.335203 -0.784238  1.748584  0.689819  1.345981  2.401481  0.555230
# 1    -0.367194  1.214139 -1.239823  0.913640 -1.108813  0.842107  0.402951
# 2    -0.223586 -0.004247 -0.753329 -0.231245  0.569146  2.014164  0.251880
# 3    -1.436968  1.467864  0.858960  0.139044  0.295012 -1.267011 -0.710657
# 4     0.762653  0.087473 -1.692083 -1.777014 -0.349183  1.095108 -1.475631
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  0.797064  0.088848  1.043295 -1.396315  1.653988 -1.805195  1.241247
# 7996 -1.751327  0.683739  0.531284  0.469559 -1.191279  0.138086  0.601826
# 7997 -1.531730  1.239963  0.375153 -0.604610  0.191582  0.452269  1.800385
# 7998 -1.617570  0.943902  0.721368  0.451608 -0.036600 -1.227781 -0.482090
# 7999 -0.805792  0.042070  0.538674  0.616728 -0.532901  1.329784 -0.629362
#
# ...

# %%
y_pred = model.predict(X_t)
y_pred
# Out:
# array([2, 5, 9, ..., 1, 8, 2], dtype=int64)

# %%
np.savetxt("pred1.csv", y_pred, delimiter=",")

# %% [markdown]
# NuSvm

# %%
model = svm.NuSVC(kernel = 'linear' ).fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.87625

# %%
model = svm.NuSVC(kernel = 'poly' ).fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.931875

# %%
model = svm.NuSVC(kernel = 'rbf' ).fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.92875

# %%
model = svm.NuSVC(kernel = 'sigmoid' ).fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.859375

# %%
y = [0.9445, 0.866,0.8570, 0.928]
z = [1, 2, 3, 4]
n = ['Polynomial', "Linear", "Sigmoid","RBF" ]

fig, ax = plt.subplots(figsize=(8,5))
ax.scatter(z, y, c='c')
ax.set_ylabel("Score")
ax.set_xlabel("Kernel")
ax.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

for i, txt in enumerate(n):
    ax.annotate(txt, (z[i], y[i]))

# %%
df_test = pd.read_csv('test 2.csv')

# %%
X_t = df_test.drop('t', axis = 'columns')
X_t
# Out:
#             x1        x2        x3        x4        x5        x6        x7  \
# 0    -0.013315  0.589281  0.592964  0.380379  0.580959 -0.256317 -0.205756
# 1    -1.001831  0.383398  0.435497  0.252344  0.664190  0.464760 -0.990111
# 2    -1.127132  0.142540  0.449842 -0.618171  0.042540 -1.574251 -1.866418
# 3    -0.291579 -1.386695  0.594485  0.002998 -0.278673  0.255857 -0.730722
# 4    -1.593340  0.839889 -0.408702  0.216184 -0.773577  0.225192 -1.296012
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -1.622967  0.712480 -0.580288  0.436993 -1.071597 -0.525745 -1.212648
# 1996  1.661141  0.885791  0.378913  1.555699 -0.721413  0.548296 -0.299093
# 1997 -1.790739  0.801121 -0.413884  0.379237 -0.706654  0.380859 -0.314835
# 1998 -1.186841 -0.354132 -0.211264 -1.705665  0.123196  0.490206 -0.919626
# 1999  0.355056  0.609191  1.997011  0.300620 -0.397564  1.581415  1.279856
#
# ...

# %%
model = svm.NuSVC(kernel = 'linear' ).fit(X_train, y_train)
model.score(Xt, yt)
# Out:
# 0.87125

# %%
model = svm.NuSVC(kernel = 'poly' ).fit(X_train, y_train)
model.score(Xt, yt)
# Out:
# 0.940625

# %%
model = svm.NuSVC(kernel = 'sigmoid' ).fit(X_train, y_train)
model.score(Xt, yt)
# Out:
# 0.848125

# %%
model = svm.NuSVC(kernel = 'rbf' ).fit(X_train, y_train)
model.score(Xt, yt)
# Out:
# 0.92375

# %%
y = [0.940625, 0.87125,0.848125, 0.92375]
z = [1, 2, 3, 4]
n = ['Polynomial', "Linear", "Sigmoid","RBF" ]

fig, ax = plt.subplots(figsize=(8,5))
ax.scatter(z, y, c='c')
ax.set_ylabel("Score")
ax.set_xlabel("Kernel")
ax.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

for i, txt in enumerate(n):
    ax.annotate(txt, (z[i], y[i]))

# %% [markdown]
# Predict:

# %%
df1 = pd.read_csv('train 2.csv')
X = df1.drop('t', axis = 'columns')
y = df1.t

# %% [markdown]
# Poly  NuSVM

# %%
model = svm.NuSVC(kernel = 'poly' ).fit(X, y)

# %%
y_pred = model.predict(Xt)


np.savetxt("pred_poly.csv", y_pred, delimiter=",")

# %%
model = svm.NuSVC(kernel = 'sigmoid' ).fit(X, y)

# %%
y_pred = model.predict(Xt)


np.savetxt("pred_rbf.csv", y_pred, delimiter=",")

# %% [markdown]
# RBF NuSVM

# %%
model = svm.NuSVC(kernel = 'rbf' ).fit(X, y)

# %%
y_pred = model.predict(Xt)


np.savetxt("pred_rbf.csv", y_pred, delimiter=",")

# %% [markdown]
# Linear OneVOne

# %%
from sklearn.svm import LinearSVC

# %%
model = OneVsOneClassifier(LinearSVC(random_state=0, C = 0.8)).fit(X, y)
# Out:
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
y_pred = model.predict(X_t)


np.savetxt("pred_LinOneVOne.csv", y_pred, delimiter=",")

# %%
y_pred
# Out:
# array([2, 5, 9, ..., 1, 4, 2], dtype=int64)

# %% [markdown]
# Linear OneVRest

# %%
model = OneVsRestClassifier(LinearSVC(random_state=0, C = 0.4)).fit(X, y)

# %%
y_pred = model.predict(X_t)


#np.savetxt("pred_LinOneVRest.csv", y_pred, delimiter=",")

# %%
X_t
# Out:
#             x1        x2        x3        x4        x5        x6        x7  \
# 0    -0.013315  0.589281  0.592964  0.380379  0.580959 -0.256317 -0.205756
# 1    -1.001831  0.383398  0.435497  0.252344  0.664190  0.464760 -0.990111
# 2    -1.127132  0.142540  0.449842 -0.618171  0.042540 -1.574251 -1.866418
# 3    -0.291579 -1.386695  0.594485  0.002998 -0.278673  0.255857 -0.730722
# 4    -1.593340  0.839889 -0.408702  0.216184 -0.773577  0.225192 -1.296012
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -1.622967  0.712480 -0.580288  0.436993 -1.071597 -0.525745 -1.212648
# 1996  1.661141  0.885791  0.378913  1.555699 -0.721413  0.548296 -0.299093
# 1997 -1.790739  0.801121 -0.413884  0.379237 -0.706654  0.380859 -0.314835
# 1998 -1.186841 -0.354132 -0.211264 -1.705665  0.123196  0.490206 -0.919626
# 1999  0.355056  0.609191  1.997011  0.300620 -0.397564  1.581415  1.279856
#
# ...

# %%
pre = pd.read_csv('trial.csv')

# %%
pred = pre['class']

# %%
d = []
i = 0.0001
while i<=10000:
    
    
    model = OneVsRestClassifier(LinearSVC(random_state=0, C = i)).fit(X, y)

    
    y_pred = model.predict(X_t)
    k = 0
    for j in range(len(pred)-1):
        if(pred[j] == y_pred[j]):
            k = k+1
        else:
            k = k
    d.append(k)
    i = i*10
# Out:
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
d
# Out:
# [622, 623, 612, 644, 658, 661, 571, 657, 632]

# %%
model = OneVsOneClassifier(LinearSVC(random_state=0, C = 1)).fit(X, y)
# Out:
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\SOBAN\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...
